# %% [markdown]
# # 01-graph-basics - Graph Basics
#
# Turn records into edge_index, features, labels, and adjacency.
#
# - Chapter guide: [`chapters/01-graph-basics/README.md`](../chapters/01-graph-basics/README.md)
# - Code: [`chapter.py`](../chapters/01-graph-basics/chapter.py)
# - Exercise: [`exercise.py`](../chapters/01-graph-basics/exercise.py)
# - Solution: [`solution.py`](../chapters/01-graph-basics/solution.py)

# %% [markdown]
# This notebook is a lightweight companion to the versioned Python scripts. Run the chapter first, inspect the output, then try the exercise before opening the solution.

# %%
import runpy
from pathlib import Path

REPO_ROOT = Path.cwd()
if not (REPO_ROOT / 'chapters').exists():
    REPO_ROOT = REPO_ROOT.parent
CHAPTER_DIR = REPO_ROOT / 'chapters/01-graph-basics'
CHAPTER_DIR

# %% [markdown]
# ## Run the chapter

# %%
runpy.run_path(str(CHAPTER_DIR / 'chapter.py'), run_name='__main__')

# %% [markdown]
# ## Try the exercise

# %%
runpy.run_path(str(CHAPTER_DIR / 'exercise.py'), run_name='__main__')

# %% [markdown]
# ## Compare with the solution

# %%
runpy.run_path(str(CHAPTER_DIR / 'solution.py'), run_name='__main__')
