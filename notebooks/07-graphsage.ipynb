# %% [markdown]
# # 07-graphsage - GraphSAGE
#
# Score new nodes with sampled neighborhood features.
#
# - Chapter guide: [`chapters/07-graphsage/README.md`](../chapters/07-graphsage/README.md)
# - Code: [`chapter.py`](../chapters/07-graphsage/chapter.py)
# - Exercise: [`exercise.py`](../chapters/07-graphsage/exercise.py)
# - Solution: [`solution.py`](../chapters/07-graphsage/solution.py)

# %% [markdown]
# This notebook is a lightweight companion to the versioned Python scripts. Run the chapter first, inspect the output, then try the exercise before opening the solution.

# %%
import runpy
from pathlib import Path

REPO_ROOT = Path.cwd()
if not (REPO_ROOT / 'chapters').exists():
    REPO_ROOT = REPO_ROOT.parent
CHAPTER_DIR = REPO_ROOT / 'chapters/07-graphsage'
CHAPTER_DIR

# %% [markdown]
# ## Run the chapter

# %%
runpy.run_path(str(CHAPTER_DIR / 'chapter.py'), run_name='__main__')

# %% [markdown]
# ## Try the exercise

# %%
runpy.run_path(str(CHAPTER_DIR / 'exercise.py'), run_name='__main__')

# %% [markdown]
# ## Compare with the solution

# %%
runpy.run_path(str(CHAPTER_DIR / 'solution.py'), run_name='__main__')
