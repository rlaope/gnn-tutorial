# %% [markdown]
# # 03-random-walk - Random Walk
#
# Sample local neighborhoods as sequences.
#
# - Chapter guide: [`chapters/03-random-walk/README.md`](../chapters/03-random-walk/README.md)
# - Code: [`chapter.py`](../chapters/03-random-walk/chapter.py)
# - Exercise: [`exercise.py`](../chapters/03-random-walk/exercise.py)
# - Solution: [`solution.py`](../chapters/03-random-walk/solution.py)

# %% [markdown]
# This notebook is a lightweight companion to the versioned Python scripts. Run the chapter first, inspect the output, then try the exercise before opening the solution.

# %%
from pathlib import Path
import runpy

REPO_ROOT = Path.cwd()
if not (REPO_ROOT / 'chapters').exists():
    REPO_ROOT = REPO_ROOT.parent
CHAPTER_DIR = REPO_ROOT / 'chapters/03-random-walk'
CHAPTER_DIR

# %% [markdown]
# ## Run the chapter

# %%
runpy.run_path(str(CHAPTER_DIR / 'chapter.py'), run_name='__main__')

# %% [markdown]
# ## Try the exercise

# %%
runpy.run_path(str(CHAPTER_DIR / 'exercise.py'), run_name='__main__')

# %% [markdown]
# ## Compare with the solution

# %%
runpy.run_path(str(CHAPTER_DIR / 'solution.py'), run_name='__main__')
