# %% [markdown]
# # 00-why-graph-learning - Why Graph Learning
#
# Map product questions to graph tasks.
#
# - Chapter guide: [`chapters/00-why-graph-learning/README.md`](../chapters/00-why-graph-learning/README.md)
# - Code: [`chapter.py`](../chapters/00-why-graph-learning/chapter.py)
# - Exercise: [`exercise.py`](../chapters/00-why-graph-learning/exercise.py)
# - Solution: [`solution.py`](../chapters/00-why-graph-learning/solution.py)

# %% [markdown]
# This notebook is a lightweight companion to the versioned Python scripts. Run the chapter first, inspect the output, then try the exercise before opening the solution.

# %%
import runpy
from pathlib import Path

REPO_ROOT = Path.cwd()
if not (REPO_ROOT / 'chapters').exists():
    REPO_ROOT = REPO_ROOT.parent
CHAPTER_DIR = REPO_ROOT / 'chapters/00-why-graph-learning'
CHAPTER_DIR

# %% [markdown]
# ## Run the chapter

# %%
runpy.run_path(str(CHAPTER_DIR / 'chapter.py'), run_name='__main__')

# %% [markdown]
# ## Try the exercise

# %%
runpy.run_path(str(CHAPTER_DIR / 'exercise.py'), run_name='__main__')

# %% [markdown]
# ## Compare with the solution

# %%
runpy.run_path(str(CHAPTER_DIR / 'solution.py'), run_name='__main__')
